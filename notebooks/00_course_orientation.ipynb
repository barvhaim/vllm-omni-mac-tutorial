# %% [markdown]
# # Start here: models, inference, and serving
#
# ## Learning goals
# - Understand what this course does and does not run on macOS
# - Separate a model, runtime, server, and application
# - Learn the course vocabulary
#
# > **Mac track:** executable cells use lightweight simulations. Boxes labelled **Linux GPU lab** show how the same concept maps to the official runtime.

# %% [markdown]
# ## The four layers
#
# ```text
# Application  -> voice assistant, image generator, robot agent
# Server       -> HTTP, streaming, admission control, metrics
# Runtime      -> scheduling, batching, memory, parallel execution
# Model        -> learned weights and architecture
# ```
#
# **vLLM-Omni is the runtime and serving layer.** It does not train a model or add modalities the model never learned.

# %%
layers={"model":"Qwen3-Omni / Qwen-Image / Qwen3-TTS","runtime":"vLLM-Omni","server":"OpenAI-style HTTP API","application":"your product"}
for layer,value in layers.items(): print(f"{layer:12} -> {value}")

# %% [markdown]
# ## Mac reality
#
# Regular vLLM has an Apple Silicon path through **vLLM-Metal**. The complete vLLM-Omni stack, including heterogeneous AR/DiT stages and production disaggregation, should be learned here on Mac and deployed on a supported Linux accelerator environment.
#
# This course therefore provides:
#
# - executable conceptual implementations on any Mac
# - real request/configuration shapes
# - source-reading pointers
# - explicit Linux GPU labs
# - no claim that a toy simulation is a production kernel

# %% [markdown]
# ## Checkpoint
#
# Classify each item: `Qwen3-Omni`, `OmniConnector`, `/v1/audio/speech`, and a voice-assistant UI.
